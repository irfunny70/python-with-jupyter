# %%
impotr pandas as pd
# Out:
#   Cell In[15], line 1
#     impotr pandas as pd
#     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
import pandas as pd

# %%
url ="https://en.wikipedia.org/wiki/World_War_II"

# %%
D = pandas.read_html(url)

# %%
D
# Out:
# [                                         World War II
#  0   .mw-parser-output .tmulti .multiimageinner{dis...  \
#  1   Date1 September 1939 – 2 September 1945[a] (6 ...
#  2                                                Date
#  3                                            Location
#  4                                              Result
#  5                                        Participants
#  6                                              Allies
#  7                              Commanders and leaders
#  8   Main Allied leaders:  Joseph Stalin  Franklin ...
#  9                               Casualties and losses
#  10  Military dead: Over 16,000,000 Civilian dead: ...
#
#                                         World War II.1
#  0   .mw-parser-output .tmulti .multiimageinner{dis...
#  1   Date1 September 1939 – 2 September 1945[a] (6 ...
#  2   1 September 1939 – 2 September 1945[a] (6 year...
#  3   Major theaters: Europe Pacific Atlantic Indian...
# ...

# %%
D =pd.read_html(url)[0]

# %%
D
# Out:
#                                          World War II
# 0   .mw-parser-output .tmulti .multiimageinner{dis...  \
# 1   Date1 September 1939 – 2 September 1945[a] (6 ...
# 2                                                Date
# 3                                            Location
# 4                                              Result
# 5                                        Participants
# 6                                              Allies
# 7                              Commanders and leaders
# 8   Main Allied leaders:  Joseph Stalin  Franklin ...
# 9                               Casualties and losses
# 10  Military dead: Over 16,000,000 Civilian dead: ...
#
#                                        World War II.1
# 0   .mw-parser-output .tmulti .multiimageinner{dis...
# 1   Date1 September 1939 – 2 September 1945[a] (6 ...
# 2   1 September 1939 – 2 September 1945[a] (6 year...
# 3   Major theaters: Europe Pacific Atlantic Indian...
# ...
